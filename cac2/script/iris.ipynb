# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

# metadata
print(iris.metadata)

# variable information
print(iris.variables)
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'ID': 191, 'type': 'NATIVE', 'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'venue': 'Significance, 2021', 'year': 2021, 'journal': 'Significance, 2021', 'DOI': '1740-9713.01589', 'URL': 'https://www.semanticscholar.o
# ...

# %% [markdown]
# # Task
# Perform an exploratory data analysis of the Iris dataset by first inspecting the structure and types of the features and target dataframes, then calculating descriptive statistics for all numerical features. Next, combine the features and target into a single DataFrame, and finally, compute descriptive statistics for each feature grouped by the 'class' variable to understand the characteristics of each Iris species and summarize key insights.

# %% [markdown]
# ## Explore Data Structure
#
# ### Subtask:
# Display the first few rows and summary information of the feature (X) and target (y) DataFrames to understand their structure and data types.

# %% [markdown]
# **Reasoning**:
# To understand the structure, data types, and presence of non-null values in the feature (X) and target (y) DataFrames, I will display their first few rows and summary information.

# %%
print("First 5 rows of X (features) DataFrame:")
print(X.head())
print("\nSummary information for X (features) DataFrame:")
X.info()

print("\nFirst 5 rows of y (target) DataFrame:")
print(y.head())
print("\nSummary information for y (target) DataFrame:")
y.info()
# Out:
# First 5 rows of X (features) DataFrame:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2970677471.py in <cell line: 0>()
#       1 print("First 5 rows of X (features) DataFrame:")
# ----> 2 print(X.head())
#       3 print("\nSummary information for X (features) DataFrame:")
#       4 X.info()
#       5
#
# NameError: name 'X' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code failed with a `NameError` because `X` and `y` were not defined in the current execution context. To fix this, I need to re-fetch the dataset and assign the features and targets to `X` and `y` respectively, ensuring they are available for the subsequent display and summary operations.

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

print("First 5 rows of X (features) DataFrame:")
print(X.head())
print("\nSummary information for X (features) DataFrame:")
X.info()

print("\nFirst 5 rows of y (target) DataFrame:")
print(y.head())
print("\nSummary information for y (target) DataFrame:")
y.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2646789000.py in <cell line: 0>()
# ----> 1 from ucimlrepo import fetch_ucirepo
#       2
#       3 # fetch dataset
#       4 iris = fetch_ucirepo(id=53)
#       5
#
# ModuleNotFoundError: No module named 'ucimlrepo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# The previous code failed because the `ucimlrepo` package was not found due to a likely kernel reset, causing a `ModuleNotFoundError`. To fix this, I need to ensure the package is installed first, and then re-execute the code to fetch the dataset and display the dataframes' information. Although `!pip install` is usually in a separate cell, as per the explicit instruction to provide the 'full fixed code' in a single `codeblock` and fix the `ModuleNotFoundError`, I will include the installation command within this block to make it self-contained and immediately executable.

# %%
pip install ucimlrepo

from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

print("First 5 rows of X (features) DataFrame:")
print(X.head())
print("\nSummary information for X (features) DataFrame:")
X.info()

print("\nFirst 5 rows of y (target) DataFrame:")
print(y.head())
print("\nSummary information for y (target) DataFrame:")
y.info()
# Out:
#   File "/tmp/ipython-input-671727550.py", line 1
#     pip install ucimlrepo
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Visualizing Feature Distributions by Class
#
# ### Subtask:
# Create scatter plots to visualize the relationships between key features (petal length, petal width, sepal length, sepal width), with points colored by the 'class' variable, to observe distinctions among the Iris species.

# %% [markdown]
# **Reasoning**:
# To visually confirm the insights from the descriptive statistics, especially regarding the differentiating power of petal dimensions, I will generate scatter plots. These plots will display the relationship between petal length and petal width, colored by species, and then sepal length and sepal width, also colored by species, to show how the different Iris classes cluster based on these measurements. `seaborn` and `matplotlib` are excellent tools for this.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot for Petal Length vs. Petal Width, colored by species
plt.figure(figsize=(10, 6))
sns.scatterplot(x='petal length', y='petal width', hue='class', data=iris_df, s=80)
plt.title('Petal Length vs. Petal Width by Iris Species')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Create a scatter plot for Sepal Length vs. Sepal Width, colored by species
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sepal length', y='sepal width', hue='class', data=iris_df, s=80)
plt.title('Sepal Length vs. Sepal Width by Iris Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# **Reasoning**:
# The `SyntaxError` occurred because `pip install` needs to be prefixed with an exclamation mark `!` in a Jupyter/Colab environment to be executed as a shell command within a Python cell. I will add `!` to `pip install ucimlrepo` to correct this, ensuring the package is installed and the subsequent data fetching and display operations run successfully.

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo

# !pip install ucimlrepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

print("First 5 rows of X (features) DataFrame:")
print(X.head())
print("\nSummary information for X (features) DataFrame:")
X.info()

print("\nFirst 5 rows of y (target) DataFrame:")
print(y.head())
print("\nSummary information for y (target) DataFrame:")
y.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-447359145.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from ucimlrepo import fetch_ucirepo
#       3
#       4 get_ipython().system('pip install ucimlrepo')
#       5
#
# ModuleNotFoundError: No module named 'ucimlrepo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# The `ModuleNotFoundError` persists because the `from ucimlrepo import fetch_ucirepo` statement is executed before the `!pip install ucimlrepo` command has a chance to complete the installation within the same cell. To ensure the module is available for import, I must place the `!pip install ucimlrepo` command at the very beginning of the cell, before any attempts to import from `ucimlrepo`.

# %%
import pandas as pd

# !pip install ucimlrepo

from ucimlrepo import fetch_ucirepo

# fetch dataset
iris = fetch_ucirepo(id=53)

# data (as pandas dataframes)
X = iris.data.features
y = iris.data.targets

print("First 5 rows of X (features) DataFrame:")
print(X.head())
print("\nSummary information for X (features) DataFrame:")
X.info()

print("\nFirst 5 rows of y (target) DataFrame:")
print(y.head())
print("\nSummary information for y (target) DataFrame:")
y.info()
# Out:
# ...
# First 5 rows of X (features) DataFrame:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#
# Summary information for X (features) DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
#
# First 5 rows of y (target) DataFrame:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# ...

# %% [markdown]
# ## Generate Descriptive Statistics for Features
#
# ### Subtask:
# Calculate and display descriptive statistics (e.g., mean, standard deviation, min, max) for all numerical features in the 'X' DataFrame.

# %% [markdown]
# **Reasoning**:
# To calculate and display descriptive statistics for all numerical features in the 'X' DataFrame, I will use the `.describe()` method.

# %%
print("Descriptive statistics for X (features) DataFrame:")
print(X.describe())
# Out:
# Descriptive statistics for X (features) DataFrame:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Combine Features and Target
#
# ### Subtask:
# Merge the feature DataFrame (X) and the target DataFrame (y) into a single DataFrame to facilitate analysis by class.

# %% [markdown]
# **Reasoning**:
# To merge the feature and target DataFrames into a single DataFrame, I will use `pd.concat()` along columns, and then display the first few rows to confirm the merge.

# %%
iris_df = pd.concat([X, y], axis=1)
print("First 5 rows of the combined iris_df:")
print(iris_df.head())
# Out:
# First 5 rows of the combined iris_df:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Grouped Descriptive Statistics
#
# ### Subtask:
# Compute descriptive statistics for each feature, grouped by the 'class' variable in the `iris_df` DataFrame, to understand the characteristics of each Iris species.

# %% [markdown]
# **Reasoning**:
# To compute descriptive statistics for each feature, grouped by the 'class' variable, I will use the `groupby()` method on the `iris_df` DataFrame, specifying 'class' as the grouping key, and then apply the `describe()` method to the grouped data.

# %%
print("Descriptive statistics for each feature, grouped by class:")
print(iris_df.groupby('class').describe())
# Out:
# Descriptive statistics for each feature, grouped by class:
#                 sepal length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal width         ... petal length      petal width         \
#                       count   mean  ...          75%  max       count   mean
# class                               ...
# Iris-setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# Iris-versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Iris-virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# class
# ...

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the key insights and interpretations derived from the descriptive tables, highlighting any notable differences or patterns among the Iris classes.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The analysis revealed clear distinguishing characteristics among the Iris classes:
#
# *   **Iris-setosa** is distinctively characterized by having the shortest and narrowest petals (mean petal length ~1.46 cm, mean petal width ~0.24 cm) and the widest sepals (mean sepal width ~3.43 cm).
# *   **Iris-versicolor** generally falls in the middle for most measurements, with moderate petal lengths (mean petal length ~4.26 cm) and widths (mean petal width ~1.32 cm), and the narrowest sepals (mean sepal width ~2.77 cm).
# *   **Iris-virginica** has the longest and widest petals (mean petal length ~5.55 cm, mean petal width ~2.03 cm) and the longest sepals (mean sepal length ~6.59 cm).
#
# The most notable differences and patterns that help distinguish the Iris classes are primarily found in the petal dimensions, with sepal width also playing a significant role in separating Iris-setosa from the other two species.
#
# ### Data Analysis Key Findings
# *   The dataset comprises 150 entries with no missing values in either features or target.
# *   The feature DataFrame (`X`) contains four numerical features: 'sepal length', 'sepal width', 'petal length', and 'petal width', all of `float64` data type.
# *   The target DataFrame (`y`) contains one column: 'class', of `object` data type, representing the species names ('Iris-setosa', 'Iris-versicolor', 'Iris-virginica').
# *   Across all species, 'petal length' (std ~1.76) and 'sepal length' (std ~0.83) show greater overall variability compared to 'sepal width' (std ~0.43) and 'petal width' (std ~0.76).
# *   **Iris-setosa** exhibits significantly smaller petal dimensions: mean petal length of approximately 1.46 cm (ranging from 1.0 to 1.9 cm) and mean petal width of about 0.24 cm (ranging from 0.1 to 0.6 cm). It also has the widest sepals with a mean sepal width of approximately 3.43 cm.
# *   **Iris-versicolor** shows intermediate values for most features: mean petal length of about 4.26 cm and mean petal width of approximately 1.32 cm. Its sepals are typically narrower, with a mean sepal width of approximately 2.77 cm.
# *   **Iris-virginica** is characterized by the largest petal dimensions: mean petal length of roughly 5.55 cm (ranging from 4.5 to 6.9 cm) and mean petal width of about 2.03 cm (ranging from 1.4 to 2.5 cm). It also has the longest sepals, with a mean sepal length of approximately 6.59 cm.
# *   Petal length and petal width appear to be the strongest differentiating features among the three Iris species, with Iris-setosa being clearly separated by its very small petals, and Iris-virginica by its very large petals.
#
# ### Insights or Next Steps
# *   **Feature Importance:** Petal length and petal width are likely the most important features for classifying Iris species, as they show the greatest distinction between classes. This suggests these features would be highly influential in any classification model.
# *   **Visualization:** Creating visualizations such as scatter plots (e.g., petal length vs. petal width, colored by class) would further highlight the observed separations and overlaps between species, providing a clear visual understanding of the data distribution.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot for Petal Length vs. Petal Width, colored by species
plt.figure(figsize=(10, 6))
sns.scatterplot(x='petal length', y='petal width', hue='class', data=iris_df, s=80)
plt.title('Petal Length vs. Petal Width by Iris Species')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Create a scatter plot for Sepal Length vs. Sepal Width, colored by species
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sepal length', y='sepal width', hue='class', data=iris_df, s=80)
plt.title('Sepal Length vs. Sepal Width by Iris Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
